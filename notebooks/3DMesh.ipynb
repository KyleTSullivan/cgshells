# %% [markdown]
# # 3D Mesh Making Notebook
#
# Creates mesh and saves topological info to files for loading into simulations.

# %%
import numpy as np
import os
import sys
import gzip
import subprocess
import importlib
import pathlib
import shutil
import yaml
import datetime
import pytz
import time
cwd = os.getcwd()
itop=cwd.find("cgshells/")+len("cgshells")
PROJECT_ROOT = cwd[:itop]
sys.path.insert(0, PROJECT_ROOT )

from utils.readsim import ReadSim
# from utils.curvsim.v1.curvamer2d import Curvamer2D
# from utils.curvsim.v1.curvamer3d import Curvamer3D
import utils.run_manager as rm
# from utils.run_manager import PROJECT_ROOT, lmpunity, lmplocal
version = "v1"    # select which version of curvsim to use
curvsim = importlib.import_module(f"utils.curvsim.{version}")
Curvamer2D = rm.load_class(version, "curvamer2d", "Curvamer2D")
Curvamer3D = rm.load_class(version, "curvamer3d", "Curvamer3D")
versionpath = "/".join(curvsim.__name__.split("."))
DATASCRIPTS = f"{versionpath}/DataScripts"    # location of compatible data scripts (relative to PROJECT_ROOT)

# rm.print_header(version)
# rm.make_simpaths_file(JOBDIR,JOB)     # make empty status file for this job

import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Make Meshes

# %%
np.sqrt(2/5)
# Out:
# 0.6324555320336759

# %%
dcore = 1.0
a = np.sqrt(2/5) * dcore
wx = 15 * dcore 
wy = 15 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 0.0min 12.0sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.6324555320336759
# curvamer width (x) = 15.17893276880822
# curvamer length (y) = 15.336231610144651
# # of sites per curvamer: 1422
# # of bonds per curvamer: 8927

# %%
dcore = 1.0
a = np.sqrt(2/5) * dcore
wx = 30 * dcore 
wy = 30 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 2.0min 44.2sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.6324555320336759
# curvamer width (x) = 29.725410005582766
# curvamer length (y) = 29.577018105278967
# # of sites per curvamer: 5226
# # of bonds per curvamer: 33365

# %%
dcore = 1.0
a = np.sqrt(2/5) * dcore
wx = 45 * dcore 
wy = 45 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 14.0min 49.9sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.6324555320336759
# curvamer width (x) = 44.90434277439099
# curvamer length (y) = 44.91324971542362
# # of sites per curvamer: 11870
# # of bonds per curvamer: 76247

# %%
dcore = 1.0
a = np.sqrt(1/5) * dcore
wx = 15 * dcore 
wy = 15 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 0.0min 32.6sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.4472135954999579
# curvamer width (x) = 15.20526224699857
# curvamer length (y) = 14.717336715588184
# # of sites per curvamer: 2692
# # of bonds per curvamer: 17062

# %%
2692/1422
# Out:
# 1.8931082981715892

# %%
1.89*11870
# Out:
# 22434.3

# %%
dcore = 1.0
a = np.sqrt(1/5) * dcore
wx = 30 * dcore 
wy = 30 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 11.0min 43.4sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.4472135954999579
# curvamer width (x) = 29.96331089849718
# curvamer length (y) = 30.20927010041785
# # of sites per curvamer: 10666
# # of bonds per curvamer: 68469

# %%
dcore = 1.0
a = np.sqrt(1/10) * dcore
wx = 15 * dcore 
wy = 15 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 2.0min 44.6sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.31622776601683794
# curvamer width (x) = 14.862705002791383
# curvamer length (y) = 14.788509052639483
# # of sites per curvamer: 5226
# # of bonds per curvamer: 33365

# %%
dcore = 1.0
a = np.sqrt(1/10) * dcore
wx = 30 * dcore 
wy = 30 * dcore 
mesh_name = "a-{:.3f}-wx-{:.2f}-wy-{:.2f}".format(a,wx,wy)
meshdesigns_dir = f"{PROJECT_ROOT}/data/3d/MeshDesigns"
mesh_dir = "{}/{}".format(meshdesigns_dir,mesh_name)  

sim = Curvamer3D(directory = ".")
sim.make_mesh(mesh_dir, a, wx, wy)
# Out:
# Mesh Calculation Runtime: 0.0hrs 43.0min 17.7sec
# Review of lattice parameters: (absolute units)
#
# lattice constant = 0.31622776601683794
# curvamer width (x) = 30.041637771599603
# curvamer length (y) = 30.124740662784134
# # of sites per curvamer: 21312
# # of bonds per curvamer: 137316
